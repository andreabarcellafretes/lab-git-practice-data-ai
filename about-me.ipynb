# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Andrea Barcella"
reason = "I want to learn Data Analytics to transform data into useful information and support decision-making"
fun_fact = "My goal is to develop the technical skills I need to start a career as a Data Analyst"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Andrea Barcella. I’m excited to learn because I want to learn Data Analytics to transform data into useful information and support decision-making. A fun fact about me is: My goal is to develop the technical skills I need to start a career as a Data Analyst.
